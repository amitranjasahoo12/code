# %%
# Import required libaraies

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings
warnings.simplefilter("ignore")

# %%
# Display Maximum columns

pd.set_option("display.max_columns",None)

# %% [markdown]
# #### 1_DataFrame leads_basic_details

# %%
data_set_1=pd.read_csv("leads_basic_details.csv")
data_set_1.head()
# Out:
#    lead_id  age  gender   current_city current_education    parent_occupation  \
# 0  USR1001   16  FEMALE      Hyderabad      Intermediate     Private Employee
# 1  USR1002   20    MALE      Bengaluru            B.Tech             Business
# 2  USR1003   20  FEMALE  Visakhapatnam            B.Tech               Lawyer
# 3  USR1004   16    MALE         Mumbai      Intermediate          IT Employee
# 4  USR1005   16    MALE        Chennai      Intermediate  Government Employee
#
#   lead_gen_source
# 0    social_media
# 1  user_referrals
# 2  user_referrals
# 3  user_referrals
# 4  user_referrals

# %%
print("Columns are :",data_set_1.columns)
print("Rows{a} and columns {b}".format(a=data_set_1.shape[0],b=data_set_1.shape[1]))
# Out:
# Columns are : Index(['lead_id', 'age', 'gender', 'current_city', 'current_education',
#        'parent_occupation', 'lead_gen_source'],
#       dtype='object')
# Rows360 and columns 7

# %% [markdown]
# #### 2_DataFrame leads_demo_watched_details.csv

# %%
data_set_2=pd.read_csv("leads_demo_watched_details.csv")
data_set_2.head()
# Out:
#    lead_id demo_watched_date language  watched_percentage
# 0  USR1002          1/4/2022   Telugu                  42
# 1  USR1003          1/7/2022   Telugu                  81
# 2  USR1004          1/2/2022   Telugu                  35
# 3  USR1005          1/3/2022    Hindi                  38
# 4  USR1006         1/12/2022    Hindi                  54

# %%
print("Columns are :",data_set_2.columns)
print("Rows{a} and columns {b}".format(a=data_set_2.shape[0],b=data_set_2.shape[1]))
# Out:
# Columns are : Index(['lead_id', 'demo_watched_date', 'language', 'watched_percentage'], dtype='object')
# Rows194 and columns 4

# %% [markdown]
# #### 3_DataFrame leads_interaction_details.csv

# %%
data_set_3=pd.read_csv("leads_interaction_details.csv")
data_set_3.head()
# Out:
#    jnr_sm_id  lead_id lead_stage call_done_date call_status  \
# 0  JNR1001MG  USR1001       lead       1/2/2022  successful
# 1  JNR1001MG  USR1001       lead       1/2/2022  successful
# 2  JNR1001MG  USR1002       lead       1/3/2022  successful
# 3  JNR1001MG  USR1002       lead       1/4/2022  successful
# 4  JNR1001MG  USR1002  awareness       1/5/2022  successful
#
#           call_reason
# 0   lead_introduction
# 1       demo_schedule
# 2   lead_introduction
# 3       demo_schedule
# 4  post_demo_followup

# %%
print("Columns are :",data_set_3.columns)
print("Rows{a} and columns {b}".format(a=data_set_3.shape[0],b=data_set_3.shape[1]))
# Out:
# Columns are : Index(['jnr_sm_id', 'lead_id', 'lead_stage', 'call_done_date', 'call_status',
#        'call_reason'],
#       dtype='object')
# Rows2192 and columns 6

# %% [markdown]
# #### 4_DataFrame leads_reasons_for_no_interest.csv

# %%
data_set_4=pd.read_csv("leads_reasons_for_no_interest.csv")
data_set_4.head()
# Out:
#    lead_id reasons_for_not_interested_in_demo  \
# 0  USR1001                No time for student
# 1  USR1003                                NaN
# 2  USR1004                                NaN
# 3  USR1005                                NaN
# 4  USR1006                                NaN
#
#   reasons_for_not_interested_to_consider reasons_for_not_interested_to_convert
# 0                                    NaN                                   NaN
# 1                    No time for student                                   NaN
# 2                  Wants offline classes                                   NaN
# 3                           Can't afford                                   NaN
# 4       Student not interested in domain                                   NaN

# %%
print("Columns are :",data_set_4.columns)
print("Rows{a} and columns {b}".format(a=data_set_4.shape[0],b=data_set_4.shape[1]))
# Out:
# Columns are : Index(['lead_id', 'reasons_for_not_interested_in_demo',
#        'reasons_for_not_interested_to_consider',
#        'reasons_for_not_interested_to_convert'],
#       dtype='object')
# Rows294 and columns 4

# %% [markdown]
# #### 5_DataFrame sales_managers_assigned_leads_details.csv

# %%
data_set_5=pd.read_csv("sales_managers_assigned_leads_details.csv")
data_set_5.head()
# Out:
#   snr_sm_id  jnr_sm_id assigned_date  cycle  lead_id
# 0  SNR501MG  JNR1001MG      1/1/2022      1  USR1001
# 1  SNR501MG  JNR1001MG      1/1/2022      1  USR1002
# 2  SNR501MG  JNR1001MG      1/1/2022      1  USR1003
# 3  SNR501MG  JNR1001MG      1/1/2022      1  USR1004
# 4  SNR501MG  JNR1001MG      1/1/2022      1  USR1005

# %%
print("Columns are :",data_set_5.columns)
print("Rows{a} and columns {b}".format(a=data_set_5.shape[0],b=data_set_5.shape[1]))
# Out:
# Columns are : Index(['snr_sm_id', 'jnr_sm_id', 'assigned_date', 'cycle', 'lead_id'], dtype='object')
# Rows360 and columns 5

# %% [markdown]
# #### Merge all Dataframes

# %%
df_1=pd.merge(data_set_1,data_set_2,on="lead_id",how='left') # Merge data set 1 and 2
df_2=pd.merge(df_1,data_set_3,on="lead_id",how='left')
df_3=pd.merge(df_2,data_set_4,on="lead_id",how='left')
data=pd.merge(df_3,data_set_5,on="lead_id",how='left') # Final dataset

# %%
data.head()
# Out:
#    lead_id  age  gender current_city current_education parent_occupation  \
# 0  USR1001   16  FEMALE    Hyderabad      Intermediate  Private Employee
# 1  USR1001   16  FEMALE    Hyderabad      Intermediate  Private Employee
# 2  USR1002   20    MALE    Bengaluru            B.Tech          Business
# 3  USR1002   20    MALE    Bengaluru            B.Tech          Business
# 4  USR1002   20    MALE    Bengaluru            B.Tech          Business
#
#   lead_gen_source demo_watched_date language  watched_percentage jnr_sm_id_x  \
# 0    social_media               NaN      NaN                 NaN   JNR1001MG
# 1    social_media               NaN      NaN                 NaN   JNR1001MG
# 2  user_referrals          1/4/2022   Telugu                42.0   JNR1001MG
# 3  user_referrals          1/4/2022   Telugu                42.0   JNR1001MG
# 4  user_referrals          1/4/2022   Telugu                42.0   JNR1001MG
#
#   lead_stage call_done_date call_status         call_reason  \
# ...

# %%
print("Columns are :",data.columns)
print("Rows : {a} and columns : {b}".format(a=data.shape[0],b=data.shape[1]))
print("Data_Type : ","\n",data.dtypes)
# Out:
# Columns are : Index(['lead_id', 'age', 'gender', 'current_city', 'current_education',
#        'parent_occupation', 'lead_gen_source', 'demo_watched_date', 'language',
#        'watched_percentage', 'jnr_sm_id_x', 'lead_stage', 'call_done_date',
#        'call_status', 'call_reason', 'reasons_for_not_interested_in_demo',
#        'reasons_for_not_interested_to_consider',
#        'reasons_for_not_interested_to_convert', 'snr_sm_id', 'jnr_sm_id_y',
#        'assigned_date', 'cycle'],
#       dtype='object')
# Rows : 2194 and columns : 22
# Data_Type :
#  lead_id                                    object
# age                                         int64
# gender                                     object
# current_city                               object
# current_education                          object
# parent_occupation                          object
# lead_gen_source                            object
# demo_watched_date                          object
# ...

# %%
#chaeck the duplicate rows
data[data.duplicated(subset=None, keep="first")]
# Out:
#       lead_id  age  gender   current_city current_education  \
# 8     USR1002   20    MALE      Bengaluru            B.Tech
# 32    USR1007   16  FEMALE      Hyderabad      Intermediate
# 91    USR1017   24    MALE      Hyderabad   Looking for Job
# 113   USR1022   24  FEMALE      Hyderabad   Looking for Job
# 122   USR1023   21  FEMALE      Hyderabad            Degree
# ...       ...  ...     ...            ...               ...
# 2104  USR1318   21    MALE         Mumbai            Degree
# 2105  USR1318   21    MALE         Mumbai            Degree
# 2128  USR1324   22  FEMALE          Kochi   Looking for Job
# 2130  USR1325   25  FEMALE          Kochi   Looking for Job
# 2155  USR1335   20    MALE  Visakhapatnam            B.Tech
#
#         parent_occupation  lead_gen_source demo_watched_date language  \
# 8                Business   user_referrals          1/4/2022   Telugu
# 32      Professor/Faculty     social_media         1/11/2022  English
# ...

# %%
data[data.duplicated(subset=["lead_id"], keep="first")]
# Out:
#       lead_id  age  gender current_city current_education parent_occupation  \
# 1     USR1001   16  FEMALE    Hyderabad      Intermediate  Private Employee
# 3     USR1002   20    MALE    Bengaluru            B.Tech          Business
# 4     USR1002   20    MALE    Bengaluru            B.Tech          Business
# 5     USR1002   20    MALE    Bengaluru            B.Tech          Business
# 6     USR1002   20    MALE    Bengaluru            B.Tech          Business
# ...       ...  ...     ...          ...               ...               ...
# 2177  USR1348   16  FEMALE        Kochi      Intermediate          Business
# 2178  USR1348   16  FEMALE        Kochi      Intermediate          Business
# 2179  USR1348   16  FEMALE        Kochi      Intermediate          Business
# 2180  USR1348   16  FEMALE        Kochi      Intermediate          Business
# 2181  USR1348   16  FEMALE        Kochi      Intermediate          Business
#
# ...

# %%
data[data.duplicated(subset=["lead_id","call_reason"], keep="first")]
# Out:
#       lead_id  age  gender   current_city current_education  \
# 8     USR1002   20    MALE      Bengaluru            B.Tech
# 11    USR1003   20  FEMALE  Visakhapatnam            B.Tech
# 19    USR1005   16    MALE        Chennai      Intermediate
# 32    USR1007   16  FEMALE      Hyderabad      Intermediate
# 35    USR1008   20    MALE      Hyderabad            B.Tech
# ...       ...  ...     ...            ...               ...
# 2152  USR1335   20    MALE  Visakhapatnam            B.Tech
# 2155  USR1335   20    MALE  Visakhapatnam            B.Tech
# 2156  USR1335   20    MALE  Visakhapatnam            B.Tech
# 2167  USR1343   24  FEMALE          Kochi   Looking for Job
# 2177  USR1348   16  FEMALE          Kochi      Intermediate
#
#         parent_occupation  lead_gen_source demo_watched_date language  \
# 8                Business   user_referrals          1/4/2022   Telugu
# 11                 Lawyer   user_referrals          1/7/2022   Telugu
# ...

# %%
data.nunique()
# Out:
# lead_id                                   360
# age                                         9
# gender                                      2
# current_city                                6
# current_education                           6
# parent_occupation                           7
# lead_gen_source                             5
# demo_watched_date                          32
# language                                    3
# watched_percentage                         86
# jnr_sm_id_x                                16
# lead_stage                                  4
# call_done_date                             40
# call_status                                 2
# call_reason                                 8
# reasons_for_not_interested_in_demo          6
# reasons_for_not_interested_to_consider      5
# reasons_for_not_interested_to_convert       5
# snr_sm_id                                   4
# jnr_sm_id_y                                16
# ...

# %%
data.shape
# Out:
# (2194, 22)

# %%
data.describe(include="object")
# Out:
#         lead_id  gender   current_city current_education    parent_occupation  \
# count      2194    2194           2194              2194                 2194
# unique      360       2              6                 6                    7
# top     USR1183  FEMALE  Visakhapatnam            B.Tech  Government Employee
# freq         11    1251            467               852                  741
#
#        lead_gen_source demo_watched_date language jnr_sm_id_x lead_stage  \
# count             2194              1578     1578        2192       2192
# unique               5                32        3          16          4
# top       social_media         1/17/2022  English   JNR1012MG       lead
# freq               501               169      928         164       1547
#
#        call_done_date call_status        call_reason  \
# count            2192        2192               2192
# unique             40           2                  8
# ...

# %% [markdown]
# ## Cehecking Missing Values

# %%
data.isnull().sum()
# Out:
# lead_id                                      0
# age                                          0
# gender                                       0
# current_city                                 0
# current_education                            0
# parent_occupation                            0
# lead_gen_source                              0
# demo_watched_date                          616
# language                                   616
# watched_percentage                         616
# jnr_sm_id_x                                  2
# lead_stage                                   2
# call_done_date                               2
# call_status                                  2
# call_reason                                  2
# reasons_for_not_interested_in_demo        1580
# reasons_for_not_interested_to_consider    1724
# reasons_for_not_interested_to_convert     1723
# snr_sm_id                                    0
# jnr_sm_id_y                                  0
# ...

# %%
def missing(dff):
    print (round((dff.isnull().sum() * 100/ len(dff)),2).sort_values(ascending=False))
    

missing(data)
# Out:
# reasons_for_not_interested_to_consider    78.58
# reasons_for_not_interested_to_convert     78.53
# reasons_for_not_interested_in_demo        72.01
# demo_watched_date                         28.08
# language                                  28.08
# watched_percentage                        28.08
# lead_stage                                 0.09
# call_reason                                0.09
# jnr_sm_id_x                                0.09
# call_done_date                             0.09
# call_status                                0.09
# assigned_date                              0.00
# jnr_sm_id_y                                0.00
# snr_sm_id                                  0.00
# lead_id                                    0.00
# age                                        0.00
# lead_gen_source                            0.00
# parent_occupation                          0.00
# current_education                          0.00
# current_city                               0.00
# ...

# %%
def rmissingvaluecol(dff, threshold):
    l = []
    l = list(dff.drop(dff.loc[:,list((100*(dff.isnull().sum()/len(dff.index)) >= threshold))].columns, 1).columns.values)
    print("# Columns having more than %s percent missing values: "%threshold, (dff.shape[1] - len(l)))
    print("Columns:\n", list(set(list((dff.columns.values))) - set(l)))
    print (round((dff.isnull().sum() * 100/ len(dff)),2).sort_values(ascending=False))
    return l


rmissingvaluecol(data,70)
# Out:
# # Columns having more than 70 percent missing values:  3
# Columns:
#  ['reasons_for_not_interested_in_demo', 'reasons_for_not_interested_to_convert', 'reasons_for_not_interested_to_consider']
# reasons_for_not_interested_to_consider    78.58
# reasons_for_not_interested_to_convert     78.53
# reasons_for_not_interested_in_demo        72.01
# demo_watched_date                         28.08
# language                                  28.08
# watched_percentage                        28.08
# lead_stage                                 0.09
# call_reason                                0.09
# jnr_sm_id_x                                0.09
# call_done_date                             0.09
# call_status                                0.09
# assigned_date                              0.00
# jnr_sm_id_y                                0.00
# snr_sm_id                                  0.00
# lead_id                                    0.00
# age                                        0.00
# ...

# %%
data["cycle"].value_counts()
# Out:
# 3    650
# 1    575
# 4    497
# 2    472
# Name: cycle, dtype: int64
